# %% [markdown]
# This Program demonstrates how panda library could be used to read different file formats and process the data

# %%
import pandas as pd

try:
    df = pd.read_csv("../dataset/sample.csv")
except Exception as e:
    print(f"Exception: {e}")

df
# Out:
#    sqft  number_of_rooms  price
# 0   500                2    150
# 1   750                3    200
# 2  1000                4    250
# 3  1250                4    300
# 4  1500                5    350
# 5  1750                5    400
# 6  2000                6    450

# %% [markdown]
# Display first three rows only

# %%
df.head(3)
# Out:
#    sqft  number_of_rooms  price
# 0   500                2    150
# 1   750                3    200
# 2  1000                4    250

# %%
# dispaly only price column from data frame
df["price"]
# Out:
# 0    150
# 1    200
# 2    250
# 3    300
# 4    350
# 5    400
# 6    450
# Name: price, dtype: int64

# %%
df[["price", "number_of_rooms"]]
# Out:
#    price  number_of_rooms
# 0    150                2
# 1    200                3
# 2    250                4
# 3    300                4
# 4    350                5
# 5    400                5
# 6    450                6

# %% [markdown]
# Below is the example how data could be filtered base on specific condition
# df[df["price"] > 350]

# %%
df[df["price"] > 350]
# Out:
#    sqft  number_of_rooms  price
# 5  1750                5    400
# 6  2000                6    450

# %% [markdown]
# Below is the example how data could be filtered base on specific condition
# df[df["price"] > 350]["sqft"]

# %%
df[df["price"] > 350]["sqft"]
# Out:
# 5    1750
# 6    2000
# Name: sqft, dtype: int64

# %% [markdown]
# In pandas queries can be used to filter data as per requirement

# %%
df.query("number_of_rooms > 4").head()
# Out:
#    sqft  number_of_rooms  price
# 4  1500                5    350
# 5  1750                5    400
# 6  2000                6    450

# %% [markdown]
# In pandas queries can be used to filter data on multiple columns as per requirement

# %%
df.query("number_of_rooms > 4 & (price > 300 & price < 450)").head()
# Out:
#    sqft  number_of_rooms  price
# 4  1500                5    350
# 5  1750                5    400
