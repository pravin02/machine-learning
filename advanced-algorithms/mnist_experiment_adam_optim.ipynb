# %% [markdown]
# Popular MNIST dataset with tensorflow neural network framework

# %%
# imports
import tensorflow as tf
import tensorflow_datasets as tfds
import matplotlib.pyplot as plt

from tensorflow.keras import Sequential
from tensorflow.keras import layers, losses

from tensorflow.keras.datasets import mnist
from tensorflow.keras.layers import Dense
from tensorflow.keras.optimizers import Adam

import numpy as np

# %%
# download and Load the MNIST dataset
mnist_dataset, mnist_info = tfds.load('mnist', with_info=True, as_supervised=True)

# split dataset into train and test datasets
train_dataset, test_dataset = mnist_dataset['train'], mnist_dataset['test']
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# File s:\repositories\python\machine-learning\venv\Lib\site-packages\tensorflow_datasets\core\utils\py_utils.py:442, in try_reraise(*args, **kwargs)
#     441 try:
# --> 442   yield
#     443 except Exception as e:  # pylint: disable=broad-except
#
# File s:\repositories\python\machine-learning\venv\Lib\site-packages\tensorflow_datasets\core\load.py:218, in builder(name, try_gcs, **builder_kwargs)
#     215   with py_utils.try_reraise(
#     216       prefix=f'Failed to construct {get_dataset_repr()}: '
#     217   ):
# --> 218     return cls(**builder_kwargs)  # pytype: disable=not-instantiable
#     220 # If neither the code nor the files are found, raise DatasetNotFoundError
#
# File s:\repositories\python\machine-learning\venv\Lib\site-packages\tensorflow_datasets\core\logging\__init__.py:296, in builder_init.<locals>.decorator(function, dsbuilder, args, kwargs)
#     295 try:
# --> 296   return function(*args, **kwargs)
#     297 except Exception:
#
# File s:\repositories\python\machine-learning\venv\Lib\site-packages\tensorflow_datasets\core\dataset_builder.py:1502, in FileReaderBuilder.__init__(self, file_format, **kwargs)
#    1492 """Initializes an instance of FileReaderBuilder.
#    1493
#    1494 Callers must pass arguments as keyword arguments.
#    (...)   1500   **kwargs: Arguments passed to `DatasetBuilder`.
#    1501 """
# -> 1502 super().__init__(**kwargs)
#    1503 self.info.set_file_format(file_format)
#
# File s:\repositories\python\machine-learning\venv\Lib\site-packages\tensorflow_datasets\core\logging\__init__.py:296, in builder_init.<locals>.decorator(function, dsbuilder, args, kwargs)
#     295 try:
# --> 296   return function(*args, **kwargs)
#     297 except Exception:
#
# File s:\repositories\python\machine-learning\venv\Lib\site-packages\tensorflow_datasets\core\dataset_builder.py:294, in DatasetBuilder.__init__(self, data_dir, config, version)
#     293 if dataset_info.dataset_info_path(self.data_path).exists():
# --> 294   self.info.read_from_directory(self._data_dir)
#     295 else:  # Use the code version (do not restore data)
#
# File s:\repositories\python\machine-learning\venv\Lib\site-packages\tensorflow_datasets\core\dataset_info.py:786, in DatasetInfo.read_from_directory(self, dataset_info_dir)
#     785   field_value.MergeFrom(field_value_restored)
# --> 786 elif field.label == field.LABEL_REPEATED:
#     787   del field_value[:]
#
# AttributeError: 'google._upb._message.FieldDescriptor' object has no attribute 'label'
#
# The above exception was the direct cause of the following exception:
#
# RuntimeError                              Traceback (most recent call last)
# Cell In[3], line 2
#       1 # download and Load the MNIST dataset
# ----> 2 mnist_dataset, mnist_info = tfds.load('mnist', with_info=True, as_supervised=True)
#       3
#       4 # split dataset into train and test datasets
#       5 train_dataset, test_dataset = mnist_dataset['train'], mnist_dataset['test']
#
# File s:\repositories\python\machine-learning\venv\Lib\site-packages\tensorflow_datasets\core\logging\__init__.py:176, in _FunctionDecorator.__call__(self, function, instance, args, kwargs)
#     174 metadata = self._start_call()
#     175 try:
# --> 176   return function(*args, **kwargs)
#     177 except Exception:
#     178   metadata.mark_error()
#
# File s:\repositories\python\machine-learning\venv\Lib\site-packages\tensorflow_datasets\core\load.py:660, in load(name, split, data_dir, batch_size, shuffle_files, download, as_supervised, decoders, read_config, with_info, builder_kwargs, download_and_prepare_kwargs, as_dataset_kwargs, try_gcs, file_format)
#     521 @tfds_logging.load()
#     522 def load(
#     523     name: str,
#    (...)    539 ):
#     540   # pylint: disable=line-too-long
#     541   """Loads the named dataset into a `tf.data.Dataset`.
#     542
#     543   `tfds.load` is a convenience method that:
#    (...)    658       Split-specific information is available in `ds_info.splits`.
#     659   """  # fmt: skip
# --> 660   dbuilder = _fetch_builder(
#     661       name=name,
#     662       data_dir=data_dir,
#     663       builder_kwargs=builder_kwargs,
#     664       try_gcs=try_gcs,
#     665   )
#     666   _download_and_prepare_builder(dbuilder, download, download_and_prepare_kwargs)
#     668   if as_dataset_kwargs is None:
#
# File s:\repositories\python\machine-learning\venv\Lib\site-packages\tensorflow_datasets\core\load.py:495, in _fetch_builder(name, data_dir, builder_kwargs, try_gcs, file_format)
#     493 if file_format is not None:
#     494   builder_kwargs['file_format'] = file_format
# --> 495 return builder(name, data_dir=data_dir, try_gcs=try_gcs, **builder_kwargs)
#
# File ~\AppData\Local\Programs\Python\Python313\Lib\contextlib.py:85, in ContextDecorator.__call__.<locals>.inner(*args, **kwds)
#      82 @wraps(func)
#      83 def inner(*args, **kwds):
#      84     with self._recreate_cm():
# ---> 85         return func(*args, **kwds)
#
# File s:\repositories\python\machine-learning\venv\Lib\site-packages\tensorflow_datasets\core\logging\__init__.py:176, in _FunctionDecorator.__call__(self, function, instance, args, kwargs)
#     174 metadata = self._start_call()
#     175 try:
# --> 176   return function(*args, **kwargs)
#     177 except Exception:
#     178   metadata.mark_error()
#
# File s:\repositories\python\machine-learning\venv\Lib\site-packages\tensorflow_datasets\core\load.py:215, in builder(name, try_gcs, **builder_kwargs)
#     212 # If code exists and loading from files was skipped (e.g. files not found),
#     213 # load from the source code.
#     214 if cls:
# --> 215   with py_utils.try_reraise(
#     216       prefix=f'Failed to construct {get_dataset_repr()}: '
#     217   ):
#     218     return cls(**builder_kwargs)  # pytype: disable=not-instantiable
#     220 # If neither the code nor the files are found, raise DatasetNotFoundError
#
# File ~\AppData\Local\Programs\Python\Python313\Lib\contextlib.py:162, in _GeneratorContextManager.__exit__(self, typ, value, traceback)
#     160     value = typ()
#     161 try:
# --> 162     self.gen.throw(value)
#     163 except StopIteration as exc:
#     164     # Suppress StopIteration *unless* it's the same exception that
#     165     # was passed to throw().  This prevents a StopIteration
#     166     # raised inside the "with" statement from being suppressed.
#     167     return exc is not value
#
# File s:\repositories\python\machine-learning\venv\Lib\site-packages\tensorflow_datasets\core\utils\py_utils.py:444, in try_reraise(*args, **kwargs)
#     442   yield
#     443 except Exception as e:  # pylint: disable=broad-except
# --> 444   reraise(e, *args, **kwargs)
#
# File s:\repositories\python\machine-learning\venv\Lib\site-packages\tensorflow_datasets\core\utils\py_utils.py:411, in reraise(e, prefix, suffix)
#     409   else:
#     410     exception = RuntimeError(f'{type(e).__name__}: {msg}')
# --> 411   raise exception from e
#     412 # Otherwise, modify the exception in-place
#     413 elif len(e.args) <= 1:
#
# RuntimeError: AttributeError: Failed to construct dataset "mnist", builder_kwargs "{'data_dir': None}": 'google._upb._message.FieldDescriptor' object has no attribute 'label'

# %%
# Load the MNIST dataset
(x_train, y_train), (x_test, y_test) = mnist.load_data()

# %%
#Displaying the n first digits in the datset
for i in range(9):
  plt.subplot(330 + 1 + i) #rows col pos
  plt.imshow(x_train[i], cmap=plt.get_cmap('gray'))
plt.show()

# %%
model = Sequential([
    layers.Flatten(input_shape=(28, 28)),
    Dense(128, activation='relu'),
    Dense(64, activation='relu'),
    Dense(32, activation='relu'),
    Dense(10, activation='linear')
])
model.compile(loss= losses.SparseCategoricalCrossentropy(from_logits=True),
              optimizer=Adam(learning_rate=1e-3) # 0.0001
              )

model.summary()
# Out:
# s:\repositories\python\machine-learning\venv\Lib\site-packages\keras\src\layers\reshaping\flatten.py:37: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# Model: "sequential_2"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ flatten_2 (Flatten)             │ (None, 784)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_8 (Dense)                 │ (None, 128)            │       100,480 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_9 (Dense)                 │ (None, 64)             │         8,256 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_10 (Dense)                │ (None, 32)             │         2,080 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_11 (Dense)                │ (None, 10)             │           330 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 111,146 (434.16 KB)
#  Trainable params: 111,146 (434.16 KB)
#  Non-trainable params: 0 (0.00 B)

# %%
# Train the model
model.fit(x_train, y_train, epochs=5)
# Out:
# Epoch 1/5
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 8s 4ms/step - loss: 1.0578
# Epoch 2/5
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 8s 4ms/step - loss: 0.2739
# Epoch 3/5
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 8s 4ms/step - loss: 0.1905
# Epoch 4/5
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 8s 4ms/step - loss: 0.1511
# Epoch 5/5
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 8s 4ms/step - loss: 0.1256

# %%
print(f'x shape {x_test.shape}')
print(f'y shape {y_test.shape}')
model.evaluate(x=x_test,y=y_test)
# Out:
# x shape (10000, 28, 28)
# y shape (10000,)
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.1720
# 0.17197458446025848

# %%
#selecting done random test data to predict over model
# input_index = random.randint(0, len(x_test));
# print(input_index)

for i in range(len(x_test)):
    #plotting input to see the content
    input = x_test[i]
    plt.subplot(330 + 1 + 1) #rows col pos
    plt.imshow(input, cmap=plt.get_cmap('gray'), label="input X")
    # predicting output
    output = np.argmax(model.predict(np.array([input])))
    print(f"Y Label: {y_test[i]}, Prediction {output}")   
    plt.show()
    if i == 50:
        break
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 98ms/step
# Y Label: 7, Prediction 7
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# Y Label: 2, Prediction 2
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# Y Label: 1, Prediction 1
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# Y Label: 0, Prediction 0
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# Y Label: 4, Prediction 4
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# Y Label: 1, Prediction 1
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step
# Y Label: 4, Prediction 4
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step
# Y Label: 9, Prediction 9
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# Y Label: 5, Prediction 5
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# Y Label: 9, Prediction 4
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# Y Label: 0, Prediction 0
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# Y Label: 6, Prediction 6
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# Y Label: 9, Prediction 9
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step
# Y Label: 0, Prediction 0
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step
# Y Label: 1, Prediction 1
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step
# Y Label: 5, Prediction 5
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# Y Label: 9, Prediction 9
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# Y Label: 7, Prediction 7
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# Y Label: 3, Prediction 3
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# Y Label: 4, Prediction 4
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# Y Label: 9, Prediction 9
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# Y Label: 6, Prediction 6
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# Y Label: 6, Prediction 6
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# Y Label: 5, Prediction 5
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# Y Label: 4, Prediction 4
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# Y Label: 0, Prediction 0
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# Y Label: 7, Prediction 7
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step
# Y Label: 4, Prediction 4
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# Y Label: 0, Prediction 0
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step
# Y Label: 1, Prediction 1
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# Y Label: 3, Prediction 3
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step
# Y Label: 1, Prediction 1
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# Y Label: 3, Prediction 3
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# Y Label: 4, Prediction 4
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# Y Label: 7, Prediction 7
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# Y Label: 2, Prediction 2
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# Y Label: 7, Prediction 7
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step
# Y Label: 1, Prediction 1
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step
# Y Label: 2, Prediction 2
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 71ms/step
# Y Label: 1, Prediction 1
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 76ms/step
# Y Label: 1, Prediction 1
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 70ms/step
# Y Label: 7, Prediction 7
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step
# Y Label: 4, Prediction 4
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# Y Label: 2, Prediction 2
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# Y Label: 3, Prediction 3
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# Y Label: 5, Prediction 5
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# Y Label: 1, Prediction 1
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# Y Label: 2, Prediction 2
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# Y Label: 4, Prediction 4
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# Y Label: 4, Prediction 4
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# Y Label: 6, Prediction 6
