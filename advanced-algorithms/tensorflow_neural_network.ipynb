# %% [markdown]
# Simple neural network using tensorflow library

# %%
import tensorflow as tf
from tensorflow.keras.layers import Dense

layer_1 = Dense(name="Layer 1",units=10, activation='sigmoid');

print(layer_1)
# Out:
# <Dense name=Layer 1, built=False>
